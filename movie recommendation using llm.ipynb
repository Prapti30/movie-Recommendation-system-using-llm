# %%
import pandas as pd
import faiss
import requests
import numpy as np

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
def create_textual_representation(row):
    textual_representation = f"""Type:{row['type']},
Title:{row['title']},
Director:{row['director']},
Cast:{row['cast']},
Released:{row['release_year']},
Genres:{row['listed_in']},

Description:{row['description']}"""
    return textual_representation

# %%
df['textual_representation']=df.apply(create_textual_representation,axis=1)

# %%
print(df['textual_representation'].values[1])
# Out:
# Type:TV Show,
# Title:Blood & Water,
# Director:nan,
# Cast:Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng,
# Released:2021,
# Genres:International TV Shows, TV Dramas, TV Mysteries,
#
# Description:After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.

# %%
pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.8.0.post1)
# Requirement already satisfied: numpy<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from faiss-cpu) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
dim=4096
index=faiss.IndexFlatL2(dim)
X=np.zeros((len(df['textual_representation']),dim),dtype='float32')

# %%
for i, representation in enumerate(df['textual_representation']):
    if i % 10 ==0:
        print("processed",str(i),"instance")
    res=requests.post('http://localhost:11434/api/embeddings',
                        json={
                            'model':'llama2',
                            'prompt':representation
                        }
                     )
    embedding = res.json()['embedding']
    X[i]=np.array(embedding)
index.add(X)
# Out:
# processed 0 instance
# processed 10 instance
# processed 20 instance
# processed 30 instance
# processed 40 instance
# processed 50 instance
# processed 60 instance
# processed 70 instance
# processed 80 instance
# processed 90 instance
# processed 100 instance
# processed 110 instance
# processed 120 instance
# processed 130 instance
# processed 140 instance
# processed 150 instance
# processed 160 instance
# processed 170 instance
# processed 180 instance
# processed 190 instance
# processed 200 instance
# processed 210 instance
# processed 220 instance
# processed 230 instance
# processed 240 instance
# processed 250 instance
# processed 260 instance
# processed 270 instance
# processed 280 instance
# processed 290 instance
# processed 300 instance
# processed 310 instance
# processed 320 instance
# processed 330 instance
# processed 340 instance
# processed 350 instance
# processed 360 instance
# processed 370 instance
# processed 380 instance
# processed 390 instance
# processed 400 instance
# processed 410 instance
# processed 420 instance
# processed 430 instance
# processed 440 instance
# processed 450 instance
# processed 460 instance
# processed 470 instance
# processed 480 instance
# processed 490 instance
# processed 500 instance
# processed 510 instance
# processed 520 instance
# processed 530 instance
# processed 540 instance
# processed 550 instance
# processed 560 instance
# processed 570 instance
# processed 580 instance
# processed 590 instance
# processed 600 instance
# processed 610 instance
# processed 620 instance
# processed 630 instance
# processed 640 instance
# processed 650 instance
# processed 660 instance
# processed 670 instance
# processed 680 instance
# processed 690 instance
# processed 700 instance
# processed 710 instance
# processed 720 instance
# processed 730 instance
# processed 740 instance
# processed 750 instance
# processed 760 instance
# processed 770 instance
# processed 780 instance
# processed 790 instance
# processed 800 instance
# processed 810 instance
# processed 820 instance
# processed 830 instance
# processed 840 instance
# processed 850 instance
# processed 860 instance
# processed 870 instance
# processed 880 instance
# processed 890 instance
# processed 900 instance
# processed 910 instance
# processed 920 instance
# processed 930 instance
# processed 940 instance
# processed 950 instance
# processed 960 instance
# processed 970 instance
# processed 980 instance
# processed 990 instance
# processed 1000 instance
# processed 1010 instance
# processed 1020 instance
# processed 1030 instance
# processed 1040 instance
# processed 1050 instance
# processed 1060 instance
# processed 1070 instance
# processed 1080 instance
# processed 1090 instance
# processed 1100 instance
# processed 1110 instance
# processed 1120 instance
# processed 1130 instance
# processed 1140 instance
# processed 1150 instance
# processed 1160 instance
# processed 1170 instance
# processed 1180 instance
# processed 1190 instance
# processed 1200 instance
# processed 1210 instance
# processed 1220 instance
# processed 1230 instance
# processed 1240 instance
# processed 1250 instance
# processed 1260 instance
# processed 1270 instance
# processed 1280 instance
# processed 1290 instance
# processed 1300 instance
# processed 1310 instance
# processed 1320 instance
# processed 1330 instance
# processed 1340 instance
# processed 1350 instance
# processed 1360 instance
# processed 1370 instance
# processed 1380 instance
# processed 1390 instance
# processed 1400 instance
# processed 1410 instance
# processed 1420 instance
# processed 1430 instance
# processed 1440 instance
# processed 1450 instance
# processed 1460 instance
# processed 1470 instance
# processed 1480 instance
# processed 1490 instance
# processed 1500 instance
# processed 1510 instance
# processed 1520 instance
# processed 1530 instance
# processed 1540 instance
# processed 1550 instance
# processed 1560 instance
# processed 1570 instance
# processed 1580 instance
# processed 1590 instance
# processed 1600 instance
# processed 1610 instance
# processed 1620 instance
# processed 1630 instance
# processed 1640 instance
# processed 1650 instance
# processed 1660 instance
# processed 1670 instance
# processed 1680 instance
# processed 1690 instance
# processed 1700 instance
# processed 1710 instance
# processed 1720 instance
# processed 1730 instance
# processed 1740 instance
# processed 1750 instance
# processed 1760 instance
# processed 1770 instance
# processed 1780 instance
# processed 1790 instance
# processed 1800 instance
# processed 1810 instance
# processed 1820 instance
# processed 1830 instance
# processed 1840 instance
# processed 1850 instance
# processed 1860 instance
# processed 1870 instance
# processed 1880 instance
# processed 1890 instance
# processed 1900 instance
# processed 1910 instance
# processed 1920 instance
# processed 1930 instance
# processed 1940 instance
# processed 1950 instance
# processed 1960 instance
# processed 1970 instance
# processed 1980 instance
# processed 1990 instance
# processed 2000 instance
# processed 2010 instance
# processed 2020 instance
# processed 2030 instance
# processed 2040 instance
# processed 2050 instance
# processed 2060 instance
# processed 2070 instance
# processed 2080 instance
# processed 2090 instance
# processed 2100 instance
# processed 2110 instance
# processed 2120 instance
# processed 2130 instance
# processed 2140 instance
# processed 2150 instance
# processed 2160 instance
# processed 2170 instance
# processed 2180 instance
# processed 2190 instance
# processed 2200 instance
# processed 2210 instance
# processed 2220 instance
# processed 2230 instance
# processed 2240 instance
# processed 2250 instance
# processed 2260 instance
# processed 2270 instance
# processed 2280 instance
# processed 2290 instance
# processed 2300 instance
# processed 2310 instance
# processed 2320 instance
# processed 2330 instance
# processed 2340 instance
# processed 2350 instance
# processed 2360 instance
# processed 2370 instance
# processed 2380 instance
# processed 2390 instance
# processed 2400 instance
# processed 2410 instance
# processed 2420 instance
# processed 2430 instance
# processed 2440 instance
# processed 2450 instance
# processed 2460 instance
# processed 2470 instance
# processed 2480 instance
# processed 2490 instance
# processed 2500 instance
# processed 2510 instance
# processed 2520 instance
# processed 2530 instance
# processed 2540 instance
# processed 2550 instance
# processed 2560 instance
# processed 2570 instance
# processed 2580 instance
# processed 2590 instance
# processed 2600 instance
# processed 2610 instance
# processed 2620 instance
# processed 2630 instance
# processed 2640 instance
# processed 2650 instance
# processed 2660 instance
# processed 2670 instance
# processed 2680 instance
# processed 2690 instance
# processed 2700 instance
# processed 2710 instance
# processed 2720 instance
# processed 2730 instance
# processed 2740 instance
# processed 2750 instance
# processed 2760 instance
# processed 2770 instance
# processed 2780 instance
# processed 2790 instance
# processed 2800 instance
# processed 2810 instance
# processed 2820 instance
# processed 2830 instance
# processed 2840 instance
# processed 2850 instance
# processed 2860 instance
# processed 2870 instance
# processed 2880 instance
# processed 2890 instance
# processed 2900 instance
# processed 2910 instance
# processed 2920 instance
# processed 2930 instance
# processed 2940 instance
# processed 2950 instance
# processed 2960 instance
# processed 2970 instance
# processed 2980 instance
# processed 2990 instance
# processed 3000 instance
# processed 3010 instance
# processed 3020 instance
# processed 3030 instance
# processed 3040 instance
# processed 3050 instance
# processed 3060 instance
# processed 3070 instance
# processed 3080 instance
# processed 3090 instance
# processed 3100 instance
# processed 3110 instance
# processed 3120 instance
# processed 3130 instance
# processed 3140 instance
# processed 3150 instance
# processed 3160 instance
# processed 3170 instance
# processed 3180 instance
# processed 3190 instance
# processed 3200 instance
# processed 3210 instance
# processed 3220 instance
# processed 3230 instance
# processed 3240 instance
# processed 3250 instance
# processed 3260 instance
# processed 3270 instance
# processed 3280 instance
# processed 3290 instance
# processed 3300 instance
# processed 3310 instance
# processed 3320 instance
# processed 3330 instance
# processed 3340 instance
# processed 3350 instance
# processed 3360 instance
# processed 3370 instance
# processed 3380 instance
# processed 3390 instance
# processed 3400 instance
# processed 3410 instance
# processed 3420 instance
# processed 3430 instance
# processed 3440 instance
# processed 3450 instance
# processed 3460 instance
# processed 3470 instance
# processed 3480 instance
# processed 3490 instance
# processed 3500 instance
# processed 3510 instance
# processed 3520 instance
# processed 3530 instance
# processed 3540 instance
# processed 3550 instance
# processed 3560 instance
# processed 3570 instance
# processed 3580 instance
# processed 3590 instance
# processed 3600 instance
# processed 3610 instance
# processed 3620 instance
# processed 3630 instance
# processed 3640 instance
# processed 3650 instance
# processed 3660 instance
# processed 3670 instance
# processed 3680 instance
# processed 3690 instance
# processed 3700 instance
# processed 3710 instance
# processed 3720 instance
# processed 3730 instance
# processed 3740 instance
# processed 3750 instance
# processed 3760 instance
# processed 3770 instance
# processed 3780 instance
# processed 3790 instance
# processed 3800 instance
# processed 3810 instance
# processed 3820 instance
# processed 3830 instance
# processed 3840 instance
# processed 3850 instance
# processed 3860 instance
# processed 3870 instance
# processed 3880 instance
# processed 3890 instance
# processed 3900 instance
# processed 3910 instance
# processed 3920 instance
# processed 3930 instance
# processed 3940 instance
# processed 3950 instance
# processed 3960 instance
# processed 3970 instance
# processed 3980 instance
# processed 3990 instance
# processed 4000 instance
# processed 4010 instance
# processed 4020 instance
# processed 4030 instance
# processed 4040 instance
# processed 4050 instance
# processed 4060 instance
# processed 4070 instance
# processed 4080 instance
# processed 4090 instance
# processed 4100 instance
# processed 4110 instance
# processed 4120 instance
# processed 4130 instance
# processed 4140 instance
# processed 4150 instance
# processed 4160 instance
# processed 4170 instance
# processed 4180 instance
# processed 4190 instance
# processed 4200 instance
# processed 4210 instance
# processed 4220 instance
# processed 4230 instance
# processed 4240 instance
# processed 4250 instance
# processed 4260 instance
# processed 4270 instance
# processed 4280 instance
# processed 4290 instance
# processed 4300 instance
# processed 4310 instance
# processed 4320 instance
# processed 4330 instance
# processed 4340 instance
# processed 4350 instance
# processed 4360 instance
# processed 4370 instance
# processed 4380 instance
# processed 4390 instance
# processed 4400 instance
# processed 4410 instance
# processed 4420 instance
# processed 4430 instance
# processed 4440 instance
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 if i % 10 ==0:
#       3     print("processed",str(i),"instance")
# ----> 4 res=requests.post('http://localhost:11434/api/embeddings',
#       5                     json={
#       6                         'model':'llama2',
#       7                         'prompt':representation
#       8                     }
#       9                  )
#      10 embedding = res.json()['embedding']
#      11 X[i]=np.array(embedding)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
faiss.write_index(index,'index')

# %%
index=faiss.read_index('index')

# %%
df[df.title.str.contains('Shutter')]
# Out:
#      show_id   type           title                                  director  \
# 1358   s1359  Movie  Shutter Island                           Martin Scorsese
# 8013   s8014  Movie         Shutter  Banjong Pisanthanakun, Parkpoom Wongpoom
#
#                                                    cast        country  \
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...  United States
# 8013  Ananda Everingham, Natthaweeranuch Thongmee, A...       Thailand
#
#              date_added  release_year rating duration  \
# 1358   February 1, 2021          2010      R  139 min
# 8013  September 5, 2018          2004  TV-MA   96 min
#
#                                 listed_in  \
# 1358                            Thrillers
# 8013  Horror Movies, International Movies
#
#                                             description  \
# 1358  A U.S. marshal's troubling visions compromise ...
# 8013  After killing a young girl in a hit-and-run ac...
#
#                                  textual_representation
# 1358  Type:Movie,\nTitle:Shutter Island,\nDirector:M...
# 8013  Type:Movie,\nTitle:Shutter,\nDirector:Banjong ...

# %%
favourite_movie=df.iloc[1358]

# %%
res=requests.post('http://localhost:11434/api/embeddings',json={
    'model':'llama2',
    'prompt':favourite_movie['textual_representation']
})

# %%
embedding = np.array([res.json()['embedding']],dtype='float32')
D,I=index.search(embedding,5)

# %%
best_matches=np.array(df['textual_representation'])[I.flatten()]

# %%
for match in best_matches:
    print("Next Movie")
    print(match)
    print()
# Out:
# Next Movie
# Type:Movie,
# Title:Zubaan,
# Director:Mozez Singh,
# Cast:Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
# Released:2015,
# Genres:Dramas, International Movies, Music & Musicals,
#
# Description:A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# Next Movie
# Type:Movie,
# Title:Zubaan,
# Director:Mozez Singh,
# Cast:Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
# Released:2015,
# Genres:Dramas, International Movies, Music & Musicals,
#
# Description:A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# Next Movie
# Type:Movie,
# Title:Zubaan,
# Director:Mozez Singh,
# Cast:Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
# Released:2015,
# Genres:Dramas, International Movies, Music & Musicals,
#
# Description:A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# Next Movie
# Type:Movie,
# Title:Zubaan,
# Director:Mozez Singh,
# Cast:Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
# Released:2015,
# Genres:Dramas, International Movies, Music & Musicals,
#
# Description:A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# Next Movie
# Type:Movie,
# Title:Zubaan,
# Director:Mozez Singh,
# Cast:Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
# Released:2015,
# Genres:Dramas, International Movies, Music & Musicals,
#
# Description:A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
